# %%
# int a;
# a = None
# a = 10
# a

# a = 10
# print(type(a))
# a = 10.20
# print(type(a))
import sys
a = None
print(sys.getsizeof(a))
# Out:
# 16

# %%
# Mutable - list, bytearray, dictionary, set - modifiable - changes you will make will be done on the same objet
# Immutable - rest all are immutable - not modifiable - changes you will make, it will create a new object

# to check mutability - Assignment operation is possible or not
# id before the chages and after the changes will remain same

# lst = [10,20,30]
# print('Before the changes ', id(lst), lst)
# lst[0] = 100    # Using assignment peration

# lst.append(1000) # Using some method
# print('After the changes ', id(lst), lst)






s = 'Python'
print(id(s))
# s[0] = "J"   Not allowed -using assignment
# print('Before the changes ', id(s), s)
# s1 = s.replace('P', 'J')
# print('After the changes ', id(s), s)
# print('After the changes ', id(s1), s1)
s = 'Jython'
print(id(s))
# Out:
# 4396419256
# 4400983152

# %%
# String data types in python
# Any value kept inside '...', "...", '''...''', """..."""

# a = "This is Python's class"
# print(a)

# a = 'This is "Python" class'
# print(a)

# a = '''This is "Python" & 'Java' class'''
# print(a)

# Triple quotation is used to write multiline strings
# a = """Lorem Ipsum is simply dummy text of the printing and typesetting industry. 
# Lorem Ipsum has been the industry standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. 
# It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. 
# It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."""
# print(a)

# String prperties in python
# 1. String is a seq
# 2. It is an ordered collection of elements - 
#     increasing order of +ve index from Left to right
#     increasing order of -ve index from right to left
# 3. Basic operation - 
#     indexing - accessing sinlgle element
#     slicing - accessing multiple elements
#     concatenation - combonation two or more string using "+" operator
#     repetition - repetition of a string for more than 1 time using "*" operator
#     Membership - to check whetehr an element or group of elemnt are part of seq
#     identity - whether both the objects are sharing the same id
#     len - returns length of the string or total no of characters in the string
# 4. +ve indexing always starts from 0 from LHS
#    +ve indexing always starts from -1 from RHS
# 5. String is immutable
    

# Basic Operation os string

# Indexing - square bracket notation - string_name[index] - returns the value at specified index
my_str = 'Lorem Ipsum has been the industrys standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book'
# Length of the string
# print('Length of string or number of charcters in the str is ', len(my_str))

# Access the last element
# print(my_str[167])
# print(my_str[-1])
# print(my_str[len(my_str)-1])

# Access the first element
# print(my_str[0])
# print(my_str[-168])
# print(my_str[-len(my_str)])


# accessing the lement at index 50
# print(my_str[50])


# Acessing the multiple elements in the string - slicing
# Syntax - my_str[start:stop:step]
# my_str[stop]

# Default value of start is 0
# Default value of step is 1
# Defaul value of stop is len(str)




# Step - 
# Slicing in forward(Left to right) direction - step +ve
# Slicing in backward(right to left) direction - step -ve

# Step size can 1, -1, 2, -2, 3, -3, 4, -4....
# 1 - every char
# 2 - every 2nd char
# 3 - every 3rd char and so on



# my_str = '''This is 
# Python class'''
# print(len(my_str))
my_str1 = 'This_is_Python_class'
# print(len(my_str1))
# Slicing till Python from begining
# print(my_str[:14])

# slice only python
# print(my_str[8:14])

# Slicing the whole string
# print(my_str[::])
# print(my_str[0:len(my_str):1])
# print(my_str[:100])

# Slcing the string in reverse order
# print(my_str[::-1])
# print(my_str[-1:-(len(my_str)+1):-1])


# slice python inreverse order
# print(my_str[-7:-13:-1])
# print(my_str[13:7:-1])

# print(my_str[:10])

# slice every 2nd character
# print(my_str1[::2])
# print(my_str1[8:13:3])

# Slicne every 2nd character in reverse order
# print(my_str1[::-2])


# Concatenation, repetition, membership and identity
# Concatenation on the string - both the operands should be of string type
# We use + operator for concatenation
# Concatenation is not possible between different data types
# print(my_str1 + ' at Learnbay')
# print(my_str1 + [10.20])

# Repetiton on the string - one of the operands should be of string type and other should be integer
# We use * operator for concatenation
# print(my_str1 * 3)
# print(my_str1 * 3.0)


#Membership - in not in
# USed to check whether the elements or group of elements are part of the seq
# print('P' in my_str1)
# print('P' not in my_str1)
# print('p' not in my_str1)

# print('Python' in my_str1)
# print('python' in my_str1)

# print('Pn' in my_str1)

# Identity operator - is is not - returns True of both operands are sharing same id elese returns False
# my_str = 'This_is_Python_class'
# print(my_str is my_str1)


# s1 = 'Python'
# s2 = 'Python'
# print(s1 is s2)








# Methods related to strings
# print(dir(str))
# 'center',  'encode', 'expandtabs', 'format_map', 
#   'ljust',''maketrans', 'partition', 
#  'rjust', 'rpartition', ' 'splitlines',  
#  'translate', 'zfill'


#  '
# capitalize() - used to capitalize the first char of the string
my_str = 'this is python class'
# str_capitalize = my_str.capitalize()
# print(str_capitalize)
# print(my_str)

# casefold and lower are both used to convert all the uppercase letters to lower case letters, casefold is more aggressive than lower
my_str = 'THIS PYTHON CLASS'
# print(my_str.lower())
# print(my_str.casefold())
# print(my_str)

# my_str1 = 'fließen'
# print(my_str1.lower())   # ASCII values
# print(my_str1.casefold())    #

# swapcase - used to swap the cases of the string
my_str1 = 'THIS IS python class'
# print(my_str1.swapcase())


# upper - converts all character in upper case
# print(my_str1.upper())


# 'startswith', 'endswith', - returns True or False based on whether the string is starting or ending with a given substring
# print(my_str1.startswith('T'))
# print(my_str1.startswith('This'))
# print(my_str1.startswith('THIS'))
# print(my_str1.startswith('IS', 8))

# print(my_str1.endswith('s'))
# print(my_str1.endswith('class'))
# print(my_str1.endswith('CLASS'))
# print(my_str1.endswith('IS', 0,7))


# title - returns a string where every first char of the word will be capitalize
# my_str1 = 'tHIS iS pYTHON cLASS'
# print(my_str1.title())


#      
# 

# Returns True o\r False based on the method
s1 = 'Python'
s2 = '718268462'
s3 = 'Python123'
s4 = 'Python #$%'
s5 = '\u00BC'
s6 = 'fließen'

# isalnum - returns True if letters are eother alphabet or numeric or alpha numeric

# print(s1.isalnum())
# print(s2.isalnum())
# print(s3.isalnum())
# print(s4.isalnum())

# 'isalpha', - returns True if all charcater are alphabet
# print(s1.isalpha())
# print(s2.isalpha())

# 'isascii', - returns True if all characters are from ASCII table
# print(s1.isascii())
# print(s2.isascii())
# print(s4.isascii())
# print(s6.isascii())


# 'isdecimal', 'isdigit', 'isnumeric',  - returns True if all characters are numeric

# print(s2.isdigit())
# print(s2.isdecimal())
# print(s2.isnumeric())

# print(s5.isdigit())
# print(s5.isdecimal())
# print(s5.isnumeric())

# 'isidentifier', - returns True if it is avalid identifier
# Exception returns. True if you will check for a keyword 
# print(s1.isidentifier())
# print(s2.isidentifier())
# print(s3.isidentifier())
# print(s4.isidentifier())
# print('if'.isidentifier())

# 'islower', 'istitle', 'isupper', - Accoridng to their functionality of string fits into that then returns True

# 'isprintable', 'isspace', 
my_str1 = 'This is \nPython class'
my_str2 = 'This is \\nPython class'
# print(my_str1, my_str1.isprintable())
# print()
# print(my_str2, my_str2.isprintable())

# find, rfind, index, rindex
# All these methods works similar
# They all returns the index of substring(Only the first occurrence) you are looking for in a given string
# find and index methods are similar and does the search from left side
# rfind and rindex methods are similar and does the search from right side
# Only diff between find and index is find returns -1 and index returns ValueError if substring is not found

my_str = "peter piper picked a Peck of pickled peppers."
# print(my_str.find('p'))
# print(my_str.find('P'))
# print(my_str.find('pic'))
# print(my_str.find('pic'))
# print(my_str.find('pic', 15, 28))
# print(my_str.find('zic'))
# print(my_str.find('P'))

# print(my_str.index('p'))
# print(my_str.index('P'))
# print(my_str.index('pic'))
# print(my_str.rindex('pic'))
# print(my_str.index('zic'))

# strip, rstrip, lstrip - used to remove the unneccesary spaces from the string from either start or end or from both, but not from in between the strings
my_str = '       This.        is.      Python class.         '
# print(my_str.strip())    # spaces from both ends
# print(my_str.lstrip())    # spaces from left ends
# print(my_str.rstrip())    # spaces from right ends

#  count() - gives teh total number of occurrences of a given substring
my_str = "peter piper picked a Peck of pickled peppers."
# print(my_str.count('pi'))
# print(my_str.count('p'))
# print(my_str.count('p', 12))
# print(my_str.count('p', 12, 15))


# replace() - replaces the old string with new string
# my_str.replace('p', 'Z')
# my_str.replace('p', 'Z', 4)


# split, rsplit, join
my_str = "peter piper picked a Peck of pickled peppers."
# Give me list of words
# print(my_str.split())   # returns a list of words

# split from 'p'
# print(my_str.split('p'))

# rsplit()
# my_str.split(' ', 3)
my_str.rsplit(' ', 3)

# join() - used to join a list of words with a separator - "sep".join(list)

# my_lst = my_str.split()
# print(my_lst)
# print(' '.join(my_lst))
# print('::'.join(my_lst))
# print('-->'.join(my_lst))

# my_str.center(200, '*')
# Out:
# ['peter piper picked a Peck', 'of', 'pickled', 'peppers.']

# %%
print('Python' + 'class')
print(10,20,30)
# Out:
# Pythonclass
# 10 20 30
